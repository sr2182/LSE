# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# #### Read RADAR csv files

# %%
lm00_csv = pd.read_csv('./Raspi_data/2023-12-10-14-18-58.csv')
lm01_csv = pd.read_csv('./Raspi_data/2023-12-10-14-20-29.csv')
lm02_csv = pd.read_csv('./Raspi_data/2023-12-10-14-21-28.csv')
lm03_csv = pd.read_csv('./Raspi_data/2023-12-10-14-24-12.csv')
lm04_csv = pd.read_csv('./Raspi_data/2023-12-10-14-30-19.csv')
lm05_csv = pd.read_csv('./Raspi_data/2023-12-10-14-31-29.csv')
lm06_csv = pd.read_csv('./Raspi_data/2023-12-10-14-35-51.csv')
lm07_csv = pd.read_csv('./Raspi_data/2023-12-10-14-37-03.csv')
lm08_csv = pd.read_csv('./Raspi_data/2023-12-10-14-39-06.csv')
lm09_csv = pd.read_csv('./Raspi_data/2023-12-10-14-41-02.csv')
lm10_csv = pd.read_csv('./Raspi_data/2023-12-10-14-42-07.csv')
lm11_csv = pd.read_csv('./Raspi_data/2023-12-10-14-43-14.csv')

# %%
lm00_csv.tail(5)
# Out:
#       frame  object_index  tlv1_range  tlv1_angle  tlv1_elevation  \
# 3008    300             8         NaN         NaN             NaN
# 3009    300             9         NaN         NaN             NaN
# 3010    300            10         NaN         NaN             NaN
# 3011    300            11         NaN         NaN             NaN
# 3012    300            12         NaN         NaN             NaN
#
#       tlv1_doppler  tlv1_x_derived  tlv1_y_derived  tlv1_z_derived  tlv7_snr  \
# 3008           NaN             NaN             NaN             NaN        -1
# 3009           NaN             NaN             NaN             NaN        -1
# 3010           NaN             NaN             NaN             NaN        -1
# 3011           NaN             NaN             NaN             NaN        -1
# 3012           NaN             NaN             NaN             NaN        -1
#
#       ...  tlv10_targetID  tlv10_x  tlv10_y  tlv10_vx  tlv10_vy  tlv10_ax  \
# ...

# %% [markdown]
# #### Remove NaN entries from data (NaN originates if no object is present in a frame)

# %%
lm00_x = [x for x in lm00_csv['tlv10_x'].values if not np.isnan(x)]
lm00_y = [y for y in lm00_csv['tlv10_y'].values if not np.isnan(y)]

lm01_x = [x for x in lm01_csv['tlv10_x'].values if not np.isnan(x)]
lm01_y = [y for y in lm01_csv['tlv10_y'].values if not np.isnan(y)]

lm02_x = [x for x in lm02_csv['tlv10_x'].values if not np.isnan(x)]
lm02_y = [y for y in lm02_csv['tlv10_y'].values if not np.isnan(y)]

lm03_x = [x for x in lm03_csv['tlv10_x'].values if not np.isnan(x)]
lm03_y = [y for y in lm03_csv['tlv10_y'].values if not np.isnan(y)]

lm04_x = [x for x in lm04_csv['tlv10_x'].values if not np.isnan(x)]
lm04_y = [y for y in lm04_csv['tlv10_y'].values if not np.isnan(y)]

lm05_x = [x for x in lm05_csv['tlv10_x'].values if not np.isnan(x)]
lm05_y = [y for y in lm05_csv['tlv10_y'].values if not np.isnan(y)]

lm06_x = [x for x in lm06_csv['tlv10_x'].values if not np.isnan(x)]
lm06_y = [y for y in lm06_csv['tlv10_y'].values if not np.isnan(y)]

lm07_x = [x for x in lm07_csv['tlv10_x'].values if not np.isnan(x)]
lm07_y = [y for y in lm07_csv['tlv10_y'].values if not np.isnan(y)]

lm08_x = [x for x in lm08_csv['tlv10_x'].values if not np.isnan(x)]
lm08_y = [y for y in lm08_csv['tlv10_y'].values if not np.isnan(y)]

lm09_x = [x for x in lm09_csv['tlv10_x'].values if not np.isnan(x)]
lm09_y = [y for y in lm09_csv['tlv10_y'].values if not np.isnan(y)]

lm10_x = [x for x in lm10_csv['tlv10_x'].values if not np.isnan(x)]
lm10_y = [y for y in lm10_csv['tlv10_y'].values if not np.isnan(y)]

lm11_x = [x for x in lm11_csv['tlv10_x'].values if not np.isnan(x)]
lm11_y = [y for y in lm11_csv['tlv10_y'].values if not np.isnan(y)]

# %% [markdown]
# #### Take mean of last 25 data points (That is the correct location of the landmark)

# %%
lm00_xy = [np.mean(lm00_x[-25:]),np.mean(lm00_y[-25:])]
lm01_xy = [np.mean(lm01_x[-25:]),np.mean(lm01_y[-25:])]
lm02_xy = [np.mean(lm02_x[-25:]),np.mean(lm02_y[-25:])]
lm03_xy = [np.mean(lm03_x[-25:]),np.mean(lm03_y[-25:])]
lm04_xy = [np.mean(lm04_x[-25:]),np.mean(lm04_y[-25:])]
lm05_xy = [np.mean(lm05_x[-25:]),np.mean(lm05_y[-25:])]
lm06_xy = [np.mean(lm06_x[-25:]),np.mean(lm06_y[-25:])]
lm07_xy = [np.mean(lm07_x[-25:]),np.mean(lm07_y[-25:])]
lm08_xy = [np.mean(lm08_x[-25:]),np.mean(lm08_y[-25:])]
lm09_xy = [np.mean(lm09_x[-25:]),np.mean(lm09_y[-25:])]
lm10_xy = [np.mean(lm10_x[-25:]),np.mean(lm10_y[-25:])]
lm11_xy = [np.mean(lm11_x[-25:]),np.mean(lm11_y[-25:])]

# %% [markdown]
# #### Extract all landmark location

# %%
all_lm_x = [lm00_xy[0],lm01_xy[0],lm02_xy[0],lm03_xy[0],lm04_xy[0],lm05_xy[0],
            lm06_xy[0],lm07_xy[0],lm08_xy[0],lm09_xy[0],lm10_xy[0],lm11_xy[0]]

all_lm_y = [lm00_xy[1],lm01_xy[1],lm02_xy[1],lm03_xy[1],lm04_xy[1],lm05_xy[1],
            lm06_xy[1],lm07_xy[1],lm08_xy[1],lm09_xy[1],lm10_xy[1],lm11_xy[1]]

# %%
plt.plot(lm00_xy[0],lm00_xy[1],'X',markersize=8,color='g',label='Start')
plt.plot(all_lm_x[1:-1],all_lm_y[1:-1],'X',markersize=8,color='r')
plt.plot(lm11_xy[0],lm11_xy[1],'X',markersize=8,color='b',label='end')
plt.legend()
plt.xlabel('Landmark x coordinates (m)')
plt.ylabel('Landmark y coordinates (m)')
plt.grid()

# %% [markdown]
# #### Create a dataframe and store it as csv

# %%
radar_xy = pd.DataFrame(columns=['x','y'])
radar_xy['x'] = all_lm_x
radar_xy['y'] = all_lm_y
radar_xy
# Out:
#            x         y
# 0   0.174978  1.258428
# 1  -0.926786  1.717481
# 2  -1.604563  2.664118
# 3  -0.991726  3.328044
# 4  -0.686409  3.815433
# 5  -0.403446  4.286010
# 6   0.207190  4.812098
# 7   0.541116  5.286738
# 8   2.266461  4.263263
# 9   1.567216  3.483018
# 10  1.122248  2.691081
# 11  0.624305  1.970487

# %%
radar_xy.to_csv('radar_xy.csv',index=False)
